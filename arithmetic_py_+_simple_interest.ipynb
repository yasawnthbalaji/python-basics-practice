# %% [markdown]
# <a href="https://colab.research.google.com/github/yasawnthbalaji/python-basics-practice/blob/master/arithmetic_py_%2B_simple_interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input(" Enter first number : "))
num2 = int(input("Enter second number : "))

print("addition",num1+num2)
print("subtraction",num1-num2)
print("multiplication",num1*num2)
print("division",num1/num2)
print("floor division",num1//num2)
print("exponent",num1**num2)
# Out:
#  Enter first number : 10
# Enter second number : 20
# addition 30
# subtraction -10
# multiplication 200
# division 0.5
# floor division 0
# exponent 100000000000000000000

# %%
c = int(input("Enter number : "))
F = (c*9/5)+32
print("converted celcius to Fharen_Heat ",F)
# Out:
# Enter number : 32
# converted celcius to Fharen_Heat  89.6

# %%
F = float(input(" Enter number : "))
c = (F-32)*5/9
print("converted fharenheat to  celcius : ",c)
# Out:
#  Enter number : 89.6
# converted fharenheat to  celcius :  32.0

# %%
p = float(input("Enter principle amount : "))
r = float(input("Enter rate of interest : "))
t = float(input("Enter time : "))
si = (p*t*r)/100
print("simple interst  :", si)
# Out:
# Enter principle amount : 50000
# Enter rate of interest : 2
# Enter time : 2
# simple interst  : 2000.0
